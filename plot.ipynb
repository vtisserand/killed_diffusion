# %%
import matplotlib.pyplot as plt
import pandas as pd

# Read the data from the CSV file
data = pd.read_csv('results.csv', header = None, sep = ' ').T.dropna()

# Plot the data
data.plot(legend=False, figsize=(10, 5))
# Out:
# <AxesSubplot:>

# %%
data_call = pd.read_csv('results_call.csv').set_index('S0')
data_call.plot()
# Out:
# <AxesSubplot:xlabel='S0'>

# %%
data_call = pd.read_csv('results_barrier.csv').set_index('S0')
data_call.plot()
# Out:
# <AxesSubplot:xlabel='S0'>

# %%
data_call = pd.read_csv('results_dnt.csv').set_index('S0')
data_call.plot()
# Out:
# <AxesSubplot:xlabel='S0'>

# %% [markdown]
# ## 2nd part : Bernoulli / bridge

# %%
data_call = pd.read_csv('results_barrier_2.csv').set_index('S0')
data_call.plot()
# Out:
# <AxesSubplot:xlabel='S0'>

# %% [markdown]
# DEBUGGER LA FONCTION BARRIER 2 !!!!

# %%
data_call = pd.read_csv('results_dnt_2.csv').set_index('S0')
data_call.plot()
# Out:
# <AxesSubplot:xlabel='S0'>
